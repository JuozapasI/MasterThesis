# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import median_abs_deviation

# %%
sc.settings.verbosity = 0             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.10.4 anndata==0.11.3 umap==0.5.7 numpy==1.26.4 scipy==1.15.1 pandas==2.2.3 scikit-learn==1.6.1 statsmodels==0.14.4 igraph==0.11.8 pynndescent==0.5.13

# %%
samples = [
    "PBMC_10x", "PBMC_10x_2", "PBMC_10x_3"
]

# %%
samples = [
    "PBMC_10x", "PBMC_10x_2", "PBMC_10x_3", "PBMC_indrops", "PBMC_indrops_2", 
    "brain", "brain_2", "eye", "eye_2", "eye_3", "lung_2", "lung_5", "lung_7", "lung_8"
]

# %% [markdown]
# # Prep

# %%
adatas = {}
for sample in samples:
    adata_10x = sc.read_10x_mtx(f'../../data/downstream/matrices/{sample}/10x/')
    adata_intergenic = sc.read_10x_mtx(f'../../data/downstream/matrices/intergenic/{sample}/')
    adatas[sample] = sc.concat([adata_10x, adata_intergenic], join = 'outer', axis = 1)
    adatas[sample].raw = adatas[sample].copy()

# %%
def is_outlier(adata, metric: str, nmads: int):
    M = adata.obs[metric]
    outlier = (M < np.median(M) - nmads * median_abs_deviation(M)) | (
        np.median(M) + nmads * median_abs_deviation(M) < M
    )
    return outlier

# %%
count_thresholds = { "PBMC_10x" : 800, "PBMC_10x_2" : 1000, "PBMC_10x_3" : 1000,
                   "PBMC_indrops" : 1000, "PBMC_indrops_2" : 3000,
                   "brain" : 700, "brain_2" : 700,
                   "eye" : 800, "eye_2" : 1000, "eye_3" : 1000,
                   "lung_2" : 2000, "lung_5" : 2000, "lung_7" : 2000, "lung_8" : 2000}

# %%
for sample in samples:
    adatas[sample].var['mt'] = adatas[sample].var_names.str.startswith('MT')
    adatas[sample].var["ribo"] = adatas[sample].var_names.str.startswith(("RPS", "RPL"))
    adatas[sample].var["hb"] = adatas[sample].var_names.str.contains(("^HB[^(P)]"))
    sc.pp.calculate_qc_metrics(adatas[sample], qc_vars=['mt', 'ribo', 'hb'], percent_top=None, log1p=True, inplace=True)
    cmask = adatas[sample].obs['total_counts'].values>count_thresholds[sample]
    adatas[sample] = adatas[sample][cmask]
    sc.pp.filter_genes(adatas[sample], min_cells=3)
    adatas[sample].obs["outlier"] = (
    is_outlier(adatas[sample], "log1p_total_counts", 5)
    | is_outlier(adatas[sample], "log1p_n_genes_by_counts", 5)
    | is_outlier(adatas[sample], "pct_counts_mt", 3)
    | (adatas[sample].obs["pct_counts_mt"] > 10)
    )
    adatas[sample] = adatas[sample][(~adatas[sample].obs.outlier)].copy()
    sc.external.pp.scrublet(adatas[sample])
    cmask = adatas[sample].obs['predicted_doublet'].values == False
    adatas[sample] = adatas[sample][cmask]

    adatas[sample].layers["celltypist"] = adatas[sample].X

    sc.pp.normalize_total(adatas[sample], target_sum=None)
    sc.pp.log1p(adatas[sample])

    sc.pp.highly_variable_genes(adatas[sample], min_mean=0.0125, max_mean=3, min_disp=0.5)
    adatas[sample] = adatas[sample][:, adatas[sample].var.highly_variable]

# %%
for sample in samples:
    sc.tl.pca(adatas[sample], svd_solver='arpack')
    #sc.pl.pca_variance_ratio(adatas[sample], log=True)

# %%
pcas = { "PBMC_10x" : 10, "PBMC_10x_2" : 10, "PBMC_10x_3" : 10,
        "PBMC_indrops" : 8, "PBMC_indrops_2" : 6,
        "brain" : 11, "brain_2" : 11,
        "eye" : 11, "eye_2" : 7, "eye_3" : 7,
        "lung_2" : 10, "lung_5" : 10, "lung_7" : 10, "lung_8" : 10}

# %%
for sample in samples:
    sc.pp.neighbors(adatas[sample], n_pcs = pcas[sample])
    sc.tl.umap(adatas[sample])

# %%
import celltypist
from celltypist import models

# %%
def CellTypist(adata):
    models.download_models(force_update=True, model=["Immune_All_Low.pkl", "Immune_All_High.pkl"])
    model_low = models.Model.load(model="Immune_All_Low.pkl")
    model_high = models.Model.load(model="Immune_All_High.pkl")
    
    adata_celltypist = adata.copy()
    adata_celltypist.X = adata.layers["celltypist"]
    sc.pp.normalize_total(adata_celltypist, target_sum = 10000)
    sc.pp.log1p(adata_celltypist)
    adata_celltypist.X = adata_celltypist.X.toarray()

    predictions_high = celltypist.annotate(adata_celltypist, model=model_high, majority_voting=True)
    predictions_high_adata = predictions_high.to_adata()
    adata.obs["celltypist_cell_label_coarse"] = predictions_high_adata.obs.loc[
        adata.obs.index, "majority_voting"]
    adata.obs["celltypist_conf_score_coarse"] = predictions_high_adata.obs.loc[
        adata.obs.index, "conf_score"]
    sc.pl.umap(adata,
        color=["celltypist_cell_label_coarse", "celltypist_conf_score_coarse"],
        frameon=False,
        sort_order=False,
        wspace=1,
        legend_loc = "on data")
    
    predictions_low = celltypist.annotate(adata_celltypist, model=model_low, majority_voting=True)
    predictions_low_adata = predictions_low.to_adata()
    adata.obs["celltypist_cell_label_fine"] = predictions_low_adata.obs.loc[
        adata.obs.index, "majority_voting"]
    adata.obs["celltypist_conf_score_fine"] = predictions_low_adata.obs.loc[
        adata.obs.index, "conf_score"]
    sc.pl.umap(adata,
        color=["celltypist_cell_label_fine", "celltypist_conf_score_fine"],
        frameon=False,
        sort_order=False,
        wspace=1)

# %%
for sample in samples:
    if sample.startswith("PBMC_10x"):
        CellTypist(adatas[sample])
        adatas[sample].obs["cell_type"] = adatas[sample].obs["celltypist_cell_label_coarse"]
# Out:
# 📜 Retrieving model list from server https://celltypist.cog.sanger.ac.uk/models/models.json
# 📚 Total models in list: 54
# 📂 Storing models in /home/MazutisLab/.celltypist/data/models
# 💾 Total models to download: 2
# 💾 Downloading model [1/2]: Immune_All_Low.pkl
# 💾 Downloading model [2/2]: Immune_All_High.pkl
# 🔬 Input data has 4320 cells and 4161 genes
# 🔗 Matching reference genes in the model
# 🧬 1776 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ... storing 'feature_types' as categorical
# 🔬 Input data has 4320 cells and 4161 genes
# 🔗 Matching reference genes in the model
# 🧬 1776 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ...

# %%
for sample in samples:
    if sample.startswith("brain"):
        sc.tl.leiden(adatas[sample], resolution=0.1, key_added="cell_type")

# %%
for sample in samples:
    if sample.startswith("PBMC_indrops"):
        sc.tl.leiden(adatas[sample], resolution=0.1, key_added="cell_type")

# %%
for sample in samples:
    if sample.startswith("eye"):
        sc.tl.leiden(adatas[sample], resolution=0.1, key_added="cell_type")

# %%
for sample in samples:
    if sample == "lung_2":
        sc.tl.leiden(adatas[sample], resolution=0.1, key_added="cell_type")
    if sample == "lung_5":
        sc.tl.leiden(adatas[sample], resolution=0.25, key_added="cell_type")
    if sample == "lung_7":
        sc.tl.leiden(adatas[sample], resolution=0.3, key_added="cell_type")
    if sample == "lung_8":
        sc.tl.leiden(adatas[sample], resolution=0.25, key_added="cell_type")

# %%
res = { "PBMC_indrops" : 0.1, "PBMC_indrops_2" : 0.1,
        "brain" : 0.1, "brain_2" : 0.1,
        "eye" : 0.1, "eye_2" : 0.1, "eye_3" : 0.1,
        "lung_2" : 0.1, "lung_5" : 0.25, "lung_7" : 0.3, "lung_8" : 0.25}

# %%
for sample in samples:
    adatas[sample].write(f"../../data/downstream/adatas/dotplots/{sample}.h5ad")

# %% [markdown]
# # Plot

# %%
adatas = {}
for sample in samples:
    adatas[sample] = sc.read_h5ad(f"../../data/downstream/adatas/dotplots/{sample}.h5ad")

# %%
adatas["PBMC_10x_2"] = adatas["PBMC_10x_2"][adatas["PBMC_10x_2"].obs["cell_type"] != "Plasma cells"]
adatas["PBMC_10x_2"] = adatas["PBMC_10x_2"][adatas["PBMC_10x_2"].obs["cell_type"] != "HSC/MPP"]
adatas["PBMC_10x_2"] = adatas["PBMC_10x_2"][adatas["PBMC_10x_2"].obs["cell_type"] != "Megakaryocytes/platelets"]

# %%
sc.pl.dotplot(adatas["PBMC_10x_3"], 
                  ["INT977", "INT1312", "INT1366", "INT1492", "INT3259", "INT6013", "INT4044", "INT4216"], 
                  groupby='cell_type', show=False, use_raw = True, title = "PBMC_10x_3")
plt.savefig("../../images/dotplots/PBMC_10x_3_dge.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Example plots (replace with your actual plotting functions)
sc.pl.dotplot(adatas["PBMC_10x"], 
                  ["INT977", "INT1312", "INT1366", "INT1492", "INT3259", "INT6013", "INT4044", "INT4216"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[0], title = "PBMC_10x")

sc.pl.dotplot(adatas["PBMC_10x_2"], 
                  ["INT977", "INT1312", "INT1366", "INT1492", "INT3259", "INT6013", "INT4044", "INT4216"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[1], title = "PBMC_10x_2")

sc.pl.dotplot(adatas["PBMC_10x_3"], 
                  ["INT977", "INT1312", "INT1366", "INT1492", "INT3259", "INT6013", "INT4044", "INT4216"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[2], title = "PBMC_10x_3")

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.savefig("../../images/dotplots/PBMC_dge.png", dpi=300)
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 12))  # 1 row, 3 columns

# Example plots (replace with your actual plotting functions)
sc.pl.dotplot(adatas["lung_2"], 
                  ["INT977", "INT1426", "INT1525", "INT1554", "INT1609"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[0][0], title = "lung_2")

sc.pl.dotplot(adatas["lung_5"], 
                  ["INT977", "INT1426", "INT1525", "INT1554", "INT1609"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[0][1], title = "lung_5")

sc.pl.dotplot(adatas["lung_7"], 
                  ["INT977", "INT1426", "INT1525", "INT1554", "INT1609"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[1][0], title = "lung_7")

sc.pl.dotplot(adatas["lung_8"], 
                  ["INT977", "INT1426", "INT1525", "INT1554", "INT1609"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[1][1], title = "lung_8")

plt.tight_layout()  # Adjust layout to prevent overlapping
#plt.savefig("../../images/dotplots/lung_dge.png", dpi=300)
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Example plots (replace with your actual plotting functions)
sc.pl.dotplot(adatas["eye"], 
                  ["INT1066", "INT1483", "INT1938", "INT196", "INT1993", "INT2008", "INT2141", "INT2209", "INT2328", "INT2456", "INT349", "INT368"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[0], title = "eye")

sc.pl.dotplot(adatas["eye_2"], 
                  ["INT1066", "INT1483", "INT1938", "INT196", "INT1993", "INT2008", "INT2141", "INT2209", "INT2328", "INT2456", "INT349", "INT368"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[1], title = "eye_2")

sc.pl.dotplot(adatas["eye_3"], 
                  ["INT1066", "INT1483", "INT1938", "INT196", "INT1993", "INT2008", "INT2141", "INT2209", "INT2328", "INT2456", "INT349", "INT368"], 
                  groupby='cell_type', show=False, use_raw = True, ax=axes[2], title = "eye_3")

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.savefig("../../images/dotplots/PBMC_dge.png", dpi=300)
plt.show()

# %%
for sample in samples:
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))  # Two subplots side by side

    ax1 = axes[0]
    title = f"{sample} (n = {adatas[sample].n_obs})"
    
    sc.pl.umap(adatas[sample], color="cell_type", show=False, title=title, size=120, ax=ax1)
    
    ax2 = axes[1]
    sc.pl.dotplot(adatas[sample], 
                  ["INT977", "INT1312", "INT1366", "INT1492", "INT3259", "INT6013", "INT4044", "INT4216"], 
                  groupby='cell_type', show=False, use_raw = True, ax=ax2)
    
    plt.tight_layout()
    
    plt.show()

# %% [markdown]
# # correlation

# %%
adata = sc.read_h5ad("../../data/downstream/adatas/dotplots/eye_3.h5ad")

# %%
imputed = sc.external.pp.magic(adata, name_list = ["INT978", "SAMD5"])

# %%
sc.pl.scatter(adata, x="INT978", y="SAMD5", use_raw = False, size = 80)
sc.pl.scatter(imputed, x="INT978", y="SAMD5", use_raw = False, size = 80)

# %%
sc.pl.scatter(imputed, x="INT978", y="SAMD5", use_raw = False, size = 80, show = False, color = 'blue')
plt.savefig("../../images/eye_3_INT978_SAMD5.png", dpi=600, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sc.pl.scatter(imputed, x="INT978", y="SAMD5", use_raw = False, size = 80, show = False, color = 'blue')
#       2 plt.savefig("../../images/eye_3_INT978_SAMD5.png", dpi=600, bbox_inches='tight')
#       3 plt.show()
#
# File ~/software/pkg/miniconda3/envs/RE/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# ...

# %%
adata = sc.read_h5ad("../../data/downstream/adatas/dotplots/PBMC_10x_2.h5ad")

# %%
gene1 = "INT33"
gene2 = "DUSP1"
imputed = sc.external.pp.magic(adata, name_list = [gene1, gene2])

fig, axs = plt.subplots(1,2, figsize = (12,5))
sc.pl.scatter(adata, x=gene1, y=gene2, use_raw = False, size = 80, show = False, ax = axs[0])
sc.pl.scatter(imputed, x=gene1, y=gene2, use_raw = False, size = 80, show = False, ax = axs[1])

plt.tight_layout()
plt.show()

# %%
sc.pl.scatter(imputed, x=gene1, y=gene2, use_raw = False, size = 80, show = False, color = 'blue')
plt.savefig("../../images/PBMC_10x_2_INT33_DUSP1.png", dpi=600, bbox_inches='tight')
plt.show()
